# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
aero = pd.read_csv('terminaldetails.csv')
aero
# Out:
#     tId      tName  airportid  dId        date  plId          plName  \
# 0     8  terminal2          1   16  2019-07-01    21          Indigo
# 1     8  terminal2          1   16  2019-07-01    21          Indigo
# 2     8  terminal2          1   16  2019-07-01    22         Emiates
# 3     8  terminal2          1   16  2019-07-01    23  Etihad Airways
# 4     8  terminal2          1   16  2019-07-01    24  Etihad Airways
# 5     7  terminal1          1   11  2019-07-01    12       space jet
# 6     7  terminal1          1   12  2019-07-02    13       space jet
# 7     7  terminal1          1   13  2019-07-03    14       space jet
# 8     7  terminal1          1   14  2019-07-04    15       space jet
# 9     7  terminal1          1   15  2019-07-05    16       space jet
# 10    7  terminal1          1   11  2019-07-01    19       Air India
#
#     plArrive plDepart  pId   pName  pArrive
# 0          1     1:30  4.0    Azim    Dubai
# 1          1     1:30  5.0    Asin    Dubai
# ...

# %%
#to get unique aeroplane names
aero.plName.unique()
# Out:
# array(['Indigo', 'Emiates', 'Etihad Airways', 'space jet', 'Air India'],
#       dtype=object)

# %%
# deleting rows containing null values. i.e, romving the details of terminal if there is no passengers
aero1 = aero.dropna( how = 'any', axis = 'rows');

# %%
aero1.head(10)
# Out:
#    tId      tName  airportid  dId        date  plId          plName  plArrive  \
# 0    8  terminal2          1   16  2019-07-01    21          Indigo         1
# 1    8  terminal2          1   16  2019-07-01    21          Indigo         1
# 2    8  terminal2          1   16  2019-07-01    22         Emiates         2
# 3    8  terminal2          1   16  2019-07-01    23  Etihad Airways         3
# 4    8  terminal2          1   16  2019-07-01    24  Etihad Airways         4
#
#   plDepart  pId   pName  pArrive
# 0     1:30  4.0    Azim    Dubai
# 1     1:30  5.0    Asin    Dubai
# 2     2:30  6.0  Manuel    Dubai
# 3     3:30  7.0     Sam      USA
# 4     4:30  8.0    John  Austria

# %%
sns.countplot(x = 'tId', data = aero)
